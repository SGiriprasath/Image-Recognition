# %%
import tensorflow as tf ## pip install tensorflow

# %%
import numpy as np ## pip install numpy

# %%
filename='activity1//giri.jpg'

# %% [markdown]
# #first method  to load an image

# %%
from IPython.display import Image

# Display the image
Image(filename='activity1/giri.jpg', width=224, height=224)

# %% [markdown]
# ##second method to laod image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename,target_size = (224,224))

# %%
import matplotlib.pyplot as plt ##conda install -c conda-forge matplotlib

# %%
plt.imshow(img)

# %% [markdown]
# #third method to load image

# %%
import cv2 ##pip install opencv-python

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg=cv2.resize(imgg,(224,224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg,cv2.COLOR_BGR2RGB))

# %% [markdown]
# #fourth method to load image

# %%
from PIL import Image ##pip install pillow

# %%
im=Image.open(filename)##PIL

# %%
im = im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# ##lets load the deeep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
 ##deep learning medel weights - pre defined

# %%
## creating a model
##training the model
## test or validate
## predict

# %%
mobile=tf.keras.applications.mobilenet_v2.MobileNetV2()

# %% [markdown]
# ## pre processing of the image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename,target_size=(224,224))

# %%
plt.imshow(img)

# %%
resized_img=image.img_to_array(img)
final_image=np.expand_dims(resized_img,axis=0) ##need fourth dimenson
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions=mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03388043', 'fountain', 0.8742536), ('n09288635', 'geyser', 0.021860788), ('n02980441', 'castle', 0.00838732), ('n02894605', 'breakwater', 0.00727619), ('n09332890', 'lakeside', 0.0055099498)]]

# %%
plt.imshow(img)

# %%
predictions=mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 50ms/step

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03388043', 'fountain', 0.8742536), ('n09288635', 'geyser', 0.021860788), ('n02980441', 'castle', 0.00838732), ('n02894605', 'breakwater', 0.00727619), ('n09332890', 'lakeside', 0.0055099498)]]
